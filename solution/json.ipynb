# %%
# The requests library in Python is a powerful tool for making HTTP requests. 
# It simplifies the process of sending requests to web servers and handling responses.
import requests

data_url="https://static.webucator.com/media/public/documents/hrleaders.json"

# Verification Disabled: Disable SSL verification as a last resort:
r = requests.get(data_url, verify=False)
records = r.json()

for i, record in enumerate(records, 1):
    player = record['Player']
    hrs = record['HR']
    year = record['Year']
    print(f'{i}. {player} hit {hrs} home runs in {year}.')
# Out:
# 1. Mark McGwire hit 70 home runs in 1998.
# 2. Sammy Sosa hit 66 home runs in 1998.
# 3. Mark McGwire hit 65 home runs in 1999.
# 4. Sammy Sosa hit 63 home runs in 1999.
# 5. Roger Maris hit 61 home runs in 1961.
# 6. Babe Ruth hit 60 home runs in 1927.
# 7. Babe Ruth hit 59 home runs in 1921.
# 8. Jimmie Foxx hit 58 home runs in 1932.
# 9. Hank Greenberg hit 58 home runs in 1938.
# 10. Hack Wilson hit 56 home runs in 1930.
# 11. Ken Griffey hit 56 home runs in 1997.
# 12. Ken Griffey hit 56 home runs in 1998.
# 13. Babe Ruth hit 54 home runs in 1928.
# 14. Mickey Mantle hit 54 home runs in 1961.
# 15. Ralph Kiner hit 54 home runs in 1949.
# 16. Babe Ruth hit 54 home runs in 1920.
# 17. Mickey Mantle hit 52 home runs in 1956.
# 18. Mark McGwire hit 52 home runs in 1996.
# 19. Willie Mays hit 52 home runs in 1965.
# 20. George Foster hit 52 home runs in 1977.
# 21. Willie Mays hit 51 home runs in 1955.
# 22. Cecil Fielder hit 51 home runs in 1990.
# 23. Ralph Kiner hit 51 home runs in 1947.
# 24. Johnny Mize hit 51 home runs in 1947.
# 25. Jimmie Foxx hit 50 home runs in 1938.
# 26. Albert Belle hit 50 home runs in 1995.
# 27. Brady Anderson hit 50 home runs in 1996.
# 28. Greg Vaughn hit 50 home runs in 1998.
# 29. Ken Griffey hit 49 home runs in 1996.
# 30. Larry Walker hit 49 home runs in 1997.
# 31. Albert Belle hit 49 home runs in 1998.
# 32. Ted Kluszewski hit 49 home runs in 1954.
# 33. Willie Mays hit 49 home runs in 1962.
# 34. Babe Ruth hit 49 home runs in 1930.
# 35. Lou Gehrig hit 49 home runs in 1934.
# 36. Lou Gehrig hit 49 home runs in 1936.
# 37. Harmon Killebrew hit 49 home runs in 1964.
# 38. Frank Robinson hit 49 home runs in 1966.
# 39. Harmon Killebrew hit 49 home runs in 1969.
# 40. Andre Dawson hit 49 home runs in 1987.
# 41. Mark McGwire hit 49 home runs in 1987.
# 42. Albert Belle hit 48 home runs in 1996.
# 43. Dave Kingman hit 48 home runs in 1979.
# 44. Mike Schmidt hit 48 home runs in 1980.
# 45. Ken Griffey hit 48 home runs in 1999.
# 46. Frank Howard hit 48 home runs in 1969.
# 47. Willie Stargell hit 48 home runs in 1971.
# 48. Harmon Killebrew hit 48 home runs in 1962.
# 49. Jimmie Foxx hit 48 home runs in 1933.
# 50. Lou Gehrig hit 47 home runs in 1927.
# 51. Andres Galarraga hit 47 home runs in 1996.
# 52. Juan Gonzalez hit 47 home runs in 1996.
# 53. George Bell hit 47 home runs in 1987.
# 54. Kevin Mitchell hit 47 home runs in 1989.
# 55. Babe Ruth hit 47 home runs in 1926.
# 56. Ralph Kiner hit 47 home runs in 1950.
# 57. Eddie Mathews hit 47 home runs in 1953.
# 58. Ted Kluszewski hit 47 home runs in 1955.
# 59. Ernie Banks hit 47 home runs in 1958.
# 60. Rafael Palmeiro hit 47 home runs in 1999.
# 61. Willie Mays hit 47 home runs in 1964.
# 62. Reggie Jackson hit 47 home runs in 1969.
# 63. Hank Aaron hit 47 home runs in 1971.
# 64. Babe Ruth hit 46 home runs in 1924.
# 65. Babe Ruth hit 46 home runs in 1929.
# 66. Lou Gehrig hit 46 home runs in 1931.
# 67. Babe Ruth hit 46 home runs in 1931.
# 68. Joe DiMaggio hit 46 home runs in 1937.
# 69. Barry Bonds hit 46 home runs in 1993.
# 70. Juan Gonzalez hit 46 home runs in 1993.
# 71. Jim Rice hit 46 home runs in 1978.
# 72. Jose Canseco hit 46 home runs in 1998.
# 73. Vinny Castilla hit 46 home runs in 1998.
# 74. Eddie Mathews hit 46 home runs in 1959.
# 75. Orlando Cepeda hit 46 home runs in 1961.
# 76. Jim Gentile hit 46 home runs in 1961.
# 77. Harmon Killebrew hit 46 home runs in 1961.
# 78. Ernie Banks hit 45 home runs in 1959.
# 79. Rocky Colavito hit 45 home runs in 1961.
# 80. Hank Aaron hit 45 home runs in 1962.
# 81. Harmon Killebrew hit 45 home runs in 1963.
# 82. Mike Schmidt hit 45 home runs in 1979.
# 83. Willie McCovey hit 45 home runs in 1969.
# 84. Johnny Bench hit 45 home runs in 1970.
# 85. Gorman Thomas hit 45 home runs in 1979.
# 86. Ken Griffey hit 45 home runs in 1993.
# 87. Juan Gonzalez hit 45 home runs in 1998.
# 88. Manny Ramirez hit 45 home runs in 1998.
# 89. Chipper Jones hit 45 home runs in 1999.
# 90. Greg Vaughn hit 45 home runs in 1999.
# 91. Manny Ramirez hit 44 home runs in 1999.
# 92. Willie Stargell hit 44 home runs in 1973.
# 93. Ernie Banks hit 44 home runs in 1955.
# 94. Hank Aaron hit 44 home runs in 1957.
# 95. Hank Aaron hit 44 home runs in 1963.
# 96. Willie McCovey hit 44 home runs in 1963.
# 97. Hank Aaron hit 44 home runs in 1966.
# 98. Harmon Killebrew hit 44 home runs in 1967.
# 99. Carl Yastrzemski hit 44 home runs in 1967.
# 100. Frank Howard hit 44 home runs in 1968.
# /Users/ted.ng/Desktop/DA/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'static.webucator.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
